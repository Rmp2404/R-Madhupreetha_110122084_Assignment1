# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

test_copy = pd.read_csv("CPC_Assignment files/test_with_predictions.csv")

# Encode categorical variables
label_encoders = {}
for col in ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'property_Area']:
    le = LabelEncoder()
    test_copy[col] = le.fit_transform(test_copy[col].astype(str))
    label_encoders[col] = le

# Split data into features and target for training the regressor
features = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
            'ApplicantIncome', 'CoapplicantIncome', "LoanAmount", 'Loan_Amount_Term', 'Credit_History', 'property_Area', 'LoanAmount_log']

loan_status_0 = test_copy[test_copy['Loan_Status'] == 0]

# Features for the regression model (excluding the target variable)
X_loan_status_0 = loan_status_0[features]

# Target variable (LoanAmount)
y_loan_status_0 = loan_status_0['LoanAmount']

X_train, X_test, y_train, y_test = train_test_split(X_loan_status_0, y_loan_status_0, test_size=0.2, random_state=42)

best_gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
best_gb_model.fit(X_train, y_train)

y_pred = best_gb_model.predict(X_test)

# Calculate the Mean Squared Error (MSE) or any other metric to evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error on Test Data: {mse}")

# Now make predictions for the full Loan_Status = 0 data
y_pred_full_loan_amount = best_gb_model.predict(X_loan_status_0)

# Add the predicted loan amounts to the dataset
loan_status_0['Predicted_LoanAmount'] = y_pred_full_loan_amount

loan_status_0['Predicted_LoanAmount'] = loan_status_0['Predicted_LoanAmount'].round(2)

print("Predicted Loan Amounts for Loan_Status = 0 :")
print(loan_status_0[['Predicted_LoanAmount']])

# Create a new column for the minimum eligible loan term for each individual
loan_status_0['Min_Eligible_Loan_Term'] = None


# Iterate through each individual to find their minimum loan duration (if term ≤ 20 years)
for index, row in loan_status_0.iterrows():
    # Filter rows for this individual with term ≤ 240 months
    eligible_terms = loan_status_0[
        (loan_status_0['Loan_Amount_Term'] <= 240) &
        (loan_status_0['Predicted_LoanAmount'] > 0) &
        (loan_status_0.index == index)  # Ensure it's for this specific person
    ]
    
    # Determine the minimum eligible term, if any
    if not eligible_terms.empty:
        loan_status_0.at[index, 'Min_Eligible_Loan_Term'] = eligible_terms['Loan_Amount_Term'].min()
    else:
        loan_status_0.at[index, 'Min_Eligible_Loan_Term'] = 'None'
    print(f"Index: {index}, Eligible Terms: {eligible_terms}")

loan_status_0 = loan_status_0.reset_index(drop=True)
test_copy.loc[test_copy['Loan_Status'] == 0, 'Min_Eligible_Loan_Term'] = loan_status_0['Min_Eligible_Loan_Term']


# Update the original dataset with the predicted loan amounts
test_copy.loc[test_copy['Loan_Status'] == 0, 'Predicted_LoanAmount'] = y_pred_full_loan_amount.round(2)

# Update the original dataset with the new column
test_copy.loc[test_copy['Loan_Status'] == 0, 'Min_Eligible_Loan_Term'] = loan_status_0['Min_Eligible_Loan_Term']


# Save the updated dataset to a new file
output_file = "CPC_Assignment files/test_with_predictions.csv"
test_copy.to_csv(output_file, index=False)
print(f"\nUpdated file written to {output_file}")

print(test_copy[test_copy['Loan_Status'] == 0][['Loan_Amount_Term', 'Min_Eligible_Loan_Term']])
# Out:
# Mean Squared Error on Test Data: 49.79994021750834
# Predicted Loan Amounts for Loan_Status = 0 :
#      Predicted_LoanAmount
# 7                  148.12
# 13                 165.98
# 25                 147.99
# 35                 175.99
# 55                 130.08
# ..                    ...
# 317                 67.07
# 325                 95.05
# 339                162.00
# 346                134.89
# 354                157.98
#
# [61 rows x 1 columns]
# Index: 7, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 13, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 25, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 35, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 55, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 58, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 63, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 66, Eligible Terms:     Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 66       1        0           0          0              0             4700
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 66                  0       135.0             180.0             0.0
#
#     property_Area  LoanAmount_log  Loan_Status  Predicted_LoanAmount  \
# 66              2        4.905275            0                134.97
#
#    Min_Eligible_Loan_Term
# 66                   None
# Index: 67, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 69, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 80, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 82, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 84, Eligible Terms:     Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 84       1        1           1          1              0             4456
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 84                  0       131.0             240.0             0.0
#
#     property_Area  LoanAmount_log  Loan_Status  Predicted_LoanAmount  \
# 84              2        4.875197            0                129.97
#
#    Min_Eligible_Loan_Term
# 84                   None
# Index: 94, Eligible Terms:     Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 94       1        0           0          0              0             4609
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 94               2333       123.0             120.0             0.0
#
#     property_Area  LoanAmount_log  Loan_Status  Predicted_LoanAmount  \
# 94              1        4.812184            0                123.48
#
#    Min_Eligible_Loan_Term
# 94                   None
# Index: 101, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 106, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 117, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 118, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 119, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 123, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 124, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 126, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 140, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 142, Eligible Terms:      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 142       1        0           0          1              1             6794
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 142                528       139.0             180.0             0.0
#
#      property_Area  LoanAmount_log  Loan_Status  Predicted_LoanAmount  \
# 142              1        4.934474            0                 139.0
#
#     Min_Eligible_Loan_Term
# 142                   None
# Index: 143, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 147, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 153, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 161, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 165, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 166, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 168, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 173, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 174, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 192, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 193, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 196, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 198, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 211, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 224, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 229, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 235, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 236, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 241, Eligible Terms:      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 241       1        1           1          0              0             3887
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 241               1517       105.0             180.0             0.0
#
#      property_Area  LoanAmount_log  Loan_Status  Predicted_LoanAmount  \
# 241              2         4.65396            0                105.03
#
#     Min_Eligible_Loan_Term
# 241                   None
# Index: 243, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 245, Eligible Terms:      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 245       1        0           0          1              1             3186
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 245               3145       150.0             180.0             0.0
#
#      property_Area  LoanAmount_log  Loan_Status  Predicted_LoanAmount  \
# 245              2        5.010635            0                 150.0
#
#     Min_Eligible_Loan_Term
# 245                   None
# Index: 250, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 255, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 265, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 266, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 268, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 273, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 274, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 278, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 293, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 301, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 311, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 317, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 325, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 339, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 346, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
# Index: 354, Eligible Terms: Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, property_Area, LoanAmount_log, Loan_Status, Predicted_LoanAmount, Min_Eligible_Loan_Term]
# Index: []
#
# Updated file written to CPC_Assignment files/test_with_predictions.csv
#      Loan_Amount_Term Min_Eligible_Loan_Term
# 7               360.0                  180.0
# 13              360.0                  120.0
# 25              360.0                   None
# 35              360.0                   None
# 55              360.0                   None
# ..                ...                    ...
# 317             360.0                    NaN
# 325             360.0                    NaN
# 339             360.0                    NaN
# 346             360.0                    NaN
# 354             360.0                    NaN
#
# [61 rows x 2 columns]
# C:\Users\R Madhapreetha\AppData\Local\Temp\ipykernel_26732\4044668019.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_status_0['Predicted_LoanAmount'] = y_pred_full_loan_amount
# C:\Users\R Madhapreetha\AppData\Local\Temp\ipykernel_26732\4044668019.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_status_0['Predicted_LoanAmount'] = loan_status_0['Predicted_LoanAmount'].round(2)
# C:\Users\R Madhapreetha\AppData\Local\Temp\ipykernel_26732\4044668019.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_status_0['Min_Eligible_Loan_Term'] = None
# C:\Users\R Madhapreetha\AppData\Local\Temp\ipykernel_26732\4044668019.py:71: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[180.0 120.0 'None' 'None' 'None' 'None' nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   test_copy.loc[test_copy['Loan_Status'] == 0, 'Min_Eligible_Loan_Term'] = loan_status_0['Min_Eligible_Loan_Term']
